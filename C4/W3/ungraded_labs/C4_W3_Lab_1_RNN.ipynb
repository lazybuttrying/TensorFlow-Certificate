# %% [markdown]
# <a href="https://colab.research.google.com/github/lazybuttrying/TensorFlow-Certificate/blob/main/C4/W3/ungraded_labs/C4_W3_Lab_1_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# **Note:** This notebook can run using TensorFlow 2.5.0

# %%
#!pip install tensorflow==2.5.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Univarient time series라면 dims = 1, Multivarient time series라면 dims=n

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# H : state vector로 Y와 동일

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.6.0

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

def trend(time, slope=0):
    return slope * time

def seasonal_pattern(season_time):
    """Just an arbitrary pattern, you can change it if you wish"""
    return np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))

def seasonality(time, period, amplitude=1, phase=0):
    """Repeats the same pattern at each period"""
    season_time = ((time + phase) % period) / period
    return amplitude * seasonal_pattern(season_time)

def noise(time, noise_level=1, seed=None):
    rnd = np.random.RandomState(seed)
    return rnd.randn(len(time)) * noise_level

time = np.arange(4 * 365 + 1, dtype="float32")
baseline = 10
series = trend(time, 0.1)  
baseline = 10
amplitude = 40
slope = 0.05
noise_level = 5

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)
# Update with noise
series += noise(time, noise_level, seed=42)

split_time = 1000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

window_size = 20
batch_size = 32
shuffle_buffer_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  dataset = tf.data.Dataset.from_tensor_slices(series)
  dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
  dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
  dataset = dataset.batch(batch_size).prefetch(1)
  return dataset

# %% [markdown]
# # Sequnce Output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# retun_sequence를 명시하지 않으면 마지막 단계로만 출력됨.
# 그런데 1차원이 아닌 2차원으로 [None, 1]이라고 나옴
#
# - None == Time stamp 수, 즉 RNN이 모든 길이의 sequence를 처리할 수 있음을 의미
# - 1인 이유 : univarient time series를 사용해서
#
#
# 만약 return_sequences=True를 적으면 n차원의 출력이 나옴

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Lambda Layer
# 무작위 설정하고 keras를 더 활용하고 싶을 때 모델 정의에서 사용
#
# x data에는 batch_size, num of time series 뿐이라, RNN을 위해 series dimensionality를 추가하기 위해 이용
#
# 출력값을 100배 크게하고 싶을 때도 이용할 수 있음. RNN은 기본 activation func가 tanh라서 필요

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Learning rate를 동적으로 조정하기
#
# 1. LearningRateScheduler Callback
# ```
# lr_schedule = tf.keras.callbacks.LearningRateScheduler(
#     lambda epoch: 1e-8 * 10**(epoch / 20))
# ```
#
#
# 2. Huber loss function
#
# 이상점에 덜 민감함
#
# 목표/최소값에 가까울 때 강하게 볼록하고 극단값에 대해 덜 가파르게 되어 L2 제곱 손실 과 L1 절대 손실 의 최상의 속성을 결합
# ```
# loss=tf.keras.losses.Huber()
# ```

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)

train_set = windowed_dataset(x_train, window_size, batch_size=128, shuffle_buffer=shuffle_buffer_size)

model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
  tf.keras.layers.SimpleRNN(40, return_sequences=True),
  tf.keras.layers.SimpleRNN(40),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])

lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-8, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 2s 15ms/step - loss: 195.5726 - mae: 196.0726
# Epoch 2/100
# 8/8 [==============================] - 0s 12ms/step - loss: 194.7820 - mae: 195.2820
# Epoch 3/100
# 8/8 [==============================] - 0s 11ms/step - loss: 193.5109 - mae: 194.0109
# Epoch 4/100
# 8/8 [==============================] - 0s 10ms/step - loss: 191.9081 - mae: 192.4081
# Epoch 5/100
# 8/8 [==============================] - 0s 11ms/step - loss: 190.0235 - mae: 190.5235
# Epoch 6/100
# 8/8 [==============================] - 0s 11ms/step - loss: 187.8582 - mae: 188.3582
# Epoch 7/100
# 8/8 [==============================] - 0s 10ms/step - loss: 185.3787 - mae: 185.8787
# Epoch 8/100
# 8/8 [==============================] - 0s 10ms/step - loss: 182.5483 - mae: 183.0483
# Epoch 9/100
# 8/8 [==============================] - 0s 11ms/step - loss: 179.3126 - mae: 179.8126
# Epoch 10/100
# ...

# %%
plt.semilogx(history.history["lr"], history.history["loss"])
plt.axis([1e-8, 1e-4, 0, 30])
# 100번의 epoch에서의 learning_rate의 변화
# 이걸 보고 learning_rate를 결정해야 함!!!
# 가장 loss가 낮으면서 안정적인 learning_rate 값은 1e-6 ~ 1e-5
# Out:
# (1e-08, 0.0001, 0.0, 30.0)

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)

dataset = windowed_dataset(x_train, window_size, batch_size=128, shuffle_buffer=shuffle_buffer_size)

model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
  tf.keras.layers.SimpleRNN(40, return_sequences=True),
  tf.keras.layers.SimpleRNN(40),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 100.0)
])

# 그래서 그 둘의 중간 값인 5*(1e-5)로 설정
optimizer = tf.keras.optimizers.SGD(learning_rate=5e-5, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
history = model.fit(dataset,epochs=400)
# Out:
# Epoch 1/400
# 8/8 [==============================] - 1s 11ms/step - loss: 81.7535 - mae: 82.2535
# Epoch 2/400
# 8/8 [==============================] - 0s 11ms/step - loss: 21.9357 - mae: 22.4301
# Epoch 3/400
# 8/8 [==============================] - 0s 10ms/step - loss: 15.9200 - mae: 16.4143
# Epoch 4/400
# 8/8 [==============================] - 0s 10ms/step - loss: 12.2880 - mae: 12.7814
# Epoch 5/400
# 8/8 [==============================] - 0s 12ms/step - loss: 10.1507 - mae: 10.6410
# Epoch 6/400
# 8/8 [==============================] - 0s 12ms/step - loss: 16.2936 - mae: 16.7878
# Epoch 7/400
# 8/8 [==============================] - 0s 10ms/step - loss: 14.1799 - mae: 14.6742
# Epoch 8/400
# 8/8 [==============================] - 0s 10ms/step - loss: 9.5471 - mae: 10.0393
# Epoch 9/400
# 8/8 [==============================] - 0s 10ms/step - loss: 8.9223 - mae: 9.4109
# Epoch 10/400
# 8/8 [==============================] - 0s 13ms/step - loss: 13.6405 - mae: 14.1348
# ...

# %%
forecast=[]
for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# 400 epoch을 돌리니 대략 6.5 오차
# 오차를 더 줄이기 위해 훈련 중의 MAE와 Loss 변화를 한 눈에 보자

# %%
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 6.528265

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
mae=history.history['mae']
loss=history.history['loss']

epochs=range(len(loss)) # Get number of epochs

#------------------------------------------------
# Plot MAE and Loss
#------------------------------------------------
plt.plot(epochs, mae, 'r')
plt.plot(epochs, loss, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["MAE", "Loss"])

plt.figure()

epochs_zoom = epochs[200:]
mae_zoom = mae[200:]
loss_zoom = loss[200:]

#------------------------------------------------
# Plot Zoomed MAE and Loss
#------------------------------------------------
plt.plot(epochs_zoom, mae_zoom, 'r')
plt.plot(epochs_zoom, loss_zoom, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["MAE", "Loss"])

plt.figure()


# 오차를 더 줄이기 위해 훈련 중의 MAE와 Loss 변화를 한 눈에 보자
#

# %% [markdown]
# epoch을 500번으로 했을 때를 찍어보니 400번부터 불안정하기 시작하여 400번까지만 함

# %% [markdown]
# ![image.png](data:image/png;base64,...)
